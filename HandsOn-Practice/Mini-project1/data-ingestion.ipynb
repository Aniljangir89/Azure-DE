# %%
# %python
dbutils.secrets.listScopes()

# %%
dbutils.secrets.list("azure-kv-scope")

# %%
storage_key = dbutils.secrets.get(
    scope="azure-kv-scope",
    key="storage-account-key"
)

print("Secret retrieved successfully")

# %%
spark.conf.set(
    "fs.azure.account.key.secondstorage89.dfs.core.windows.net",
    storage_key
)

# %%
# read the customer data-
df_customers = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv("abfss://raw-data@secondstorage89.dfs.core.windows.net/customers/")
)

# %%
# read the order data -

df_orders = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv("abfss://raw-data@secondstorage89.dfs.core.windows.net/orders/")
)

# %%
# read the order review data -
df_order_reviews = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv("abfss://raw-data@secondstorage89.dfs.core.windows.net/reviews/")
)

# %%
# read the order item-
df_order_items = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv("abfss://raw-data@secondstorage89.dfs.core.windows.net/order-items/")

)

# %%
# read the geo location data

df_geolocation = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv("abfss://raw-data@secondstorage89.dfs.core.windows.net/geolocations/")
)

# %%
df_payments = (
    spark.read
    .option("header","true")
    .option("inferSchema", "true")
    .csv("abfss://raw-data@secondstorage89.dfs.core.windows.net/payments/")
)

# %%
df_products =(
    spark.read
    .option("header","true")
    .option("inferSchema", "true")
    .csv("abfss://raw-data@secondstorage89.dfs.core.windows.net/products/")
)
df_sellers = (
    spark.read
    .option("header","true")
    .option("inferSchema","true")
    .csv("abfss://raw-data@secondstorage89.dfs.core.windows.net/sellers/")
)

# %%
df_sellers.show(10)

# %%
df.show(30)

# %%
df.printSchema()

# %%
df.count()

# %%
silver_df = df.dropDuplicates()

# %%
df.count()
